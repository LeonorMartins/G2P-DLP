# %% [markdown]
# # Python Translineação

# %%
# !pip install pandas
# !pip install regex
# !pip install odfpy
# Out:
# Requirement already satisfied: pandas in c:\users\leonor martins\desktop\código\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\leonor martins\desktop\código\.venv\lib\site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\leonor martins\desktop\código\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\leonor martins\desktop\código\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\leonor martins\desktop\código\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\leonor martins\desktop\código\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: regex in c:\users\leonor martins\desktop\código\.venv\lib\site-packages (2024.11.6)
# Collecting odfpy
#   Using cached odfpy-1.4.1-py2.py3-none-any.whl
# Collecting defusedxml (from odfpy)
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Installing collected packages: defusedxml, odfpy
# Successfully installed defusedxml-0.7.1 odfpy-1.4.1

# %%
import pandas as pd
import regex as re  # Use the regex module for variable-width look-behinds

# %% [markdown]
# ## Carregar coluna para lista
#
# Esta função permite bla

# %%
def load_column_to_list(file_path, sheet_name):
    try:
        df = pd.read_excel(file_path, sheet_name=sheet_name, header=None)
        column_data = df[0].dropna().tolist()
        return column_data
    except FileNotFoundError:
        print(f"Error: The file at {file_path} was not found.")
    except ValueError as e:
        print(f"Error: {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# %% [markdown]
# ## Carregar Regex para um dicionário
#
# Esta função ahahahaha

# %%
def load_regex_to_dict(file_path, sheet_name):
    try:
        df = pd.read_excel(file_path, sheet_name=sheet_name, header=None)
        # Convert all keys and values to strings
        regex_dict = {str(k): {"replacement": str(v), "id": i }for k, v, i in zip(df[0], df[1], df[2])}
        return regex_dict
    except FileNotFoundError:
        print(f"Error: The file at {file_path} was not found.")
    except ValueError as e:
        print(f"Error: {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# %% [markdown]
# ## Aplicar os padrões

# %%
def apply_patterns_to_words(words_list, regex_dict, log_file_path="debug_silaba_notebook.txt"):
    results = []
    with open(log_file_path, "w", encoding="utf-8") as log_file:
        for word in words_list:
            processed_word = word
            used_ids = []  # guardar os IDs usados nesta palavra
            for pattern, data in regex_dict.items():
                replacement = data["replacement"]
                rule_id = data["id"]
                try:
                    if replacement == "nan":
                        replacement = ""
                    new_word = re.sub(pattern, replacement, processed_word)
                    if new_word != processed_word:
                        used_ids.append(rule_id)
                        log_file.write(f"Original Word: {processed_word} -> Processed Word: {new_word}\n")
                        log_file.write(f"Pattern Applied: {pattern} -> {replacement} (Pattern id: {rule_id})\n\n")
                    processed_word = new_word
                except re.error as e:
                    print(f"Regex error for pattern '{pattern}': {e}")
            results.append((processed_word, used_ids))
    return results

# %% [markdown]
# ## Ficheiros
# - Silaba.ods= ficheiro no formato excel com a lista de palavras do corpus 1
# -

# %%
file_path = "Silaba.ods"  # Replace with your ODS file path
folha_palavras = "Palavras"  # Replace with the desired sheet name
folha_expressoes = "ExpressoesSilaba"

# %% [markdown]
# ## Execução das funções

# %%
words_list = load_column_to_list(file_path, folha_palavras)
regex_dict = load_regex_to_dict(file_path, folha_expressoes)

# %%
print(words_list)
print(regex_dict)
# Out:
# ['alto', 'amarelo', 'amigo', 'antigo', 'assado', 'azul', 'baixo', 'belo', 'bom', 'bonito', 'branco', 'capaz', 'caro', 'castanho', 'cheio', 'chinês', 'claro', 'comprido', 'contente', 'diferente', 'difícil', 'doce', 'enorme', 'escuro', 'estranho', 'fácil', 'famoso', 'feliz', 'fino', 'forte', 'fresco', 'frio', 'grande', 'igual', 'importante', 'junto', 'leve', 'limpo', 'lindo', 'livre', 'longo', 'mau', 'natural', 'negro', 'normal', 'novo', 'obrigado', 'ótimo', 'passado', 'pequeno', 'pobre', 'português', 'possível', 'preciso', 'preto', 'principal', 'pronto', 'quente', 'rico', 'seco', 'simpático', 'simples', 'sozinho', 'triste', 'último', 'velho', 'vermelho', 'vivo', 'agora', 'aí', 'ainda', 'ali', 'amanhã', 'apenas', 'aqui', 'assim', 'até', 'bastante', 'bem', 'cá', 'cedo', 'demasiado', 'depois', 'depressa', 'embora', 'então', 'entretanto', 'finalmente', 'geralmente', 'hoje', 'imenso', 'já', 'lá', 'logo', 'longe', 'mais', 'mal', 'menos', 'mesmo', 'muito', 'nada', 'não', 'nem', 'normalmente', 'nunca', 'ora', 'pois', 'portanto', 'pouco', 'primeiro', 'quase', 'rapidamente', 'sempre', 'sim', 'só', 'sobretudo', 'talvez', 'também', 'tanto', 'tão', 'tarde', 'o', 'um', 'ao', 'como', 'e', 'enquanto', 'mas', 'ou', 'para', 'pois', 'por', 'porque', 'quando', 'que', 'se', 'sem', 'ah', 'ó', 'oh', 'olá', 'abóbora', 'abraço', 'abril', 'ação', 'acidente', 'açúcar', 'adulto', 'agosto', 'água', 'ajuda', 'aldeia', 'alegria', 'alho', 'almoço', 'altura', 'aluno', 'amizade', 'amor', 'animal', 'ano', 'apartamento', 'ar', 'área', 'armário', 'arroz', 'artigo', 'árvore', 'asa', 'atenção', 'atividade', 'ator', 'aula', 'autor', 'ave', 'avenida', 'avião', 'avô', 'azeite', 'bacalhau', 'bairro', 'banho', 'barba', 'barco', 'barulho', 'batata', 'bebé', 'bebida', 'beijinho', 'bicicleta', 'bife', 'bilhete', 'boa-tarde', 'boca', 'boi', 'bola', 'bolo', 'bom-dia', 'boneca', 'boneco', 'braço', 'brinquedo', 'buraco', 'cabeça', 'cabelo', 'caderno', 'café', 'calor', 'cama', 'caminho', 'camisa', 'campo', 'canção', 'canela', 'canto', 'cão', 'cara', 'carnaval', 'carne', 'carro', 'carta', 'casa', 'casca', 'caso', 'castanha', 'cavalo', 'cebola', 'cenoura', 'centro', 'certeza', 'céu', 'chão', 'chave', 'cheiro', 'chocolate', 'chouriço', 'chuva', 'cidade', 'cigarra', 'cinema', 'cliente', 'clube', 'coelho', 'coisa', 'colega', 'colher', 'comboio', 'comida', 'compra', 'concurso', 'consulta', 'conta', 'conversa', 'copo', 'cor', 'coração', 'corda', 'corpo', 'costa', 'cozinha', 'creme', 'criança', 'cuidado', 'curso', 'data', 'dedo', 'dente', 'desculpa', 'desporto', 'deus', 'dezembro', 'dia', 'dinheiro', 'direito', 'doença', 'domingo', 'dono', 'doutor', 'empresa', 'entrada', 'equipa', 'escola', 'espaço', 'espera', 'estudante', 'estudo', 'euro', 'exemplo', 'fada', 'família', 'farinha', 'feijão', 'feira', 'férias', 'festa', 'filho', 'filme', 'fim', 'fim-de-semana', 'final', 'flor', 'folha', 'força', 'forma', 'formiga', 'forno', 'frase', 'frente', 'fruta', 'fruto', 'fundo', 'futebol', 'futuro', 'galo', 'gato', 'gema', 'gente', 'golo', 'gosto', 'gota', 'grupo', 'guerra', 'história', 'homem', 'hora', 'horário', 'horta', 'hospital', 'hotel', 'idade', 'ideia', 'ilha', 'imagem', 'início', 'inverno', 'irmão', 'janeiro', 'janela', 'jardim', 'jogador', 'jogo', 'jovem', 'julho', 'junho', 'lado', 'leão', 'legume', 'leite', 'lenda', 'letra', 'língua', 'linha', 'lista', 'livro', 'local', 'loja', 'lua', 'lugar', 'lume', 'luz', 'macaco', 'madeira', 'maio', 'mala', 'mamã', 'maneira', 'manhã', 'manteiga', 'mão', 'máquina', 'mar', 'marca', 'março', 'margarina', 'marido', 'mata', 'material', 'médico', 'medo', 'meia', 'meio', 'mel', 'menino', 'mês', 'mesa', 'metro', 'minuto', 'modo', 'momento', 'montanha', 'morte', 'mosca', 'mulher', 'mundo', 'museu', 'música', 'natal', 'natureza', 'neve', 'noite', 'nome', 'notícia', 'novembro', 'noz', 'número', 'nuvem', 'obra', 'olho', 'origem', 'osso', 'outono', 'outubro', 'ovo', 'padre', 'pai', 'país', 'palavra', 'panela', 'pão', 'papel', 'parede', 'parte', 'pássaro', 'passo' ...
# {'(?<=[lmnrsx])(?=[bcçdfgjlmnpqrstvxz])': {'replacement': '.', 'id': 'S1'}, '(?<=[aáàâãeéèêiìíîoóòôõuúùû])(?![lmnrsxz])(?=[bcçdfgjpqrtv])': {'replacement': '.', 'id': 'S2'}, '(?<=[aáàâãeéèêiìíîoóòôõuúùû])(?=[lmnrsxz][aáàâãeéèêiìíîoóòôõuúùû])': {'replacement': '.', 'id': 'S3'}, '(?<=[aáàâãeéèêiìíîoóòôõuúùû])(?=(lh|nh))': {'replacement': '.', 'id': 'S4'}, '(?<=(ai|ei|oi|ui|au|eu|iu|ou))(?=[aáàâãeéèêiìíîoóòôõuúùû])': {'replacement': '.', 'id': 'S5'}, '(?<=[aáàâãeéèêiìíîoóòôõuúùû])(?=(ão))': {'replacement': '.', 'id': 'S6'}, '(?<=[ieo])(?=[aeo])': {'replacement': '.', 'id': 'S7'}, '(?<=[bcçdfhjlmnpsrtvxz]u)(?=a)': {'replacement': '.', 'id': 'S8'}, '(?<=a)(?=i[r]$)': {'replacement': '.', 'id': 'S9'}, '(?<=a)(?=in)': {'replacement': '.', 'id': 'S10'}, '(?<=a)(?=[íú])': {'replacement': '.', 'id': 'S11'}, '-': {'replacement': ' ', 'id': 'S12'}}

# %%
if words_list and regex_dict:
    processed_data = apply_patterns_to_words(words_list, regex_dict)
    
    # Criar uma lista de dicionários com os dados necessários
    results_for_df = []
    for original, (processed, ids_used) in zip(words_list, processed_data):
        results_for_df.append({
            "Original": original,
            "Processado": processed,
            "IDs usados": ", ".join(ids_used) if ids_used else ""
        })
    
    # Criar o DataFrame
    df_resultados = pd.DataFrame(results_for_df)
    
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.width', 0):
    print(df_resultados)
# Out:
#           Original       Processado   IDs usados
# 0             alto            al.to           S1
# 1          amarelo       a.ma.re.lo           S3
# 2            amigo          a.mi.go       S2, S3
# 3           antigo         an.ti.go       S1, S2
# 4           assado         as.sa.do       S1, S2
# 5             azul            a.zul           S3
# 6            baixo           bai.xo           S3
# 7             belo            be.lo           S3
# 8              bom              bom
# 9           bonito         bo.ni.to       S2, S3
# 10          branco          bran.co           S1
# 11           capaz           ca.paz           S2
# 12            caro            ca.ro           S3
# 13        castanho       cas.ta.nho       S1, S4
# 14           cheio           chei.o           S5
# 15          chinês          chi.nês           S3
# 16           claro           cla.ro           S3
# 17        comprido       com.pri.do       S1, S2
# 18        contente       con.ten.te           S1
# 19       diferente     di.fe.ren.te   S1, S2, S3
# 20         difícil        di.fí.cil           S2
# 21            doce            do.ce           S2
# 22          enorme         e.nor.me       S1, S3
# 23          escuro         es.cu.ro       S1, S3
# 24        estranho       es.tra.nho       S1, S4
# 25           fácil           fá.cil           S2
# 26          famoso         fa.mo.so           S3
# 27           feliz           fe.liz           S3
# 28            fino            fi.no           S3
# 29           forte           for.te           S1
# 30          fresco          fres.co           S1
# 31            frio            fri.o           S7
# 32          grande          gran.de           S1
# 33           igual           i.gual           S2
# 34      importante    im.por.tan.te           S1
# 35           junto           jun.to           S1
# 36            leve            le.ve           S2
# 37           limpo           lim.po           S1
# 38           lindo           lin.do           S1
# 39           livre           li.vre           S2
# 40           longo           lon.go           S1
# 41             mau              mau
# 42         natural        na.tu.ral       S2, S3
# 43           negro           ne.gro           S2
# 44          normal          nor.mal           S1
# 45            novo            no.vo           S2
# 46        obrigado      o.bri.ga.do           S2
# 47           ótimo          ó.ti.mo       S2, S3
# 48         passado        pas.sa.do       S1, S2
# 49         pequeno        pe.que.no       S2, S3
# 50           pobre           po.bre           S2
# 51       português      por.tu.guês       S1, S2
# 52        possível       pos.sí.vel       S1, S2
# 53         preciso        pre.ci.so       S2, S3
# 54           preto           pre.to           S2
# 55       principal      prin.ci.pal       S1, S2
# 56          pronto          pron.to           S1
# 57          quente          quen.te           S1
# 58            rico            ri.co           S2
# 59            seco            se.co           S2
# 60       simpático     sim.pá.ti.co       S1, S2
# 61         simples         sim.ples           S1
# 62         sozinho        so.zi.nho       S3, S4
# 63          triste          tris.te           S1
# 64          último         úl.ti.mo       S1, S3
# 65           velho           ve.lho           S4
# 66        vermelho       ver.me.lho       S1, S4
# 67            vivo            vi.vo           S2
# 68           agora          a.go.ra       S2, S3
# 69              aí              a.í          S11
# 70           ainda          a.in.da      S1, S10
# 71             ali             a.li           S3
# 72          amanhã         a.ma.nhã       S3, S4
# 73          apenas         a.pe.nas       S2, S3
# 74            aqui            a.qui           S2
# 75           assim           as.sim           S1
# 76             até             a.té           S2
# 77        bastante       bas.tan.te           S1
# 78             bem              bem
# 79              cá               cá
# 80            cedo            ce.do           S2
# 81       demasiado    de.ma.si.a.do   S2, S3, S7
# 82          depois          de.pois           S2
# 83        depressa       de.pres.sa       S1, S2
# 84          embora         em.bo.ra       S1, S3
# 85           então           en.tão           S1
# 86      entretanto    en.tre.tan.to       S1, S2
# 87      finalmente    fi.nal.men.te       S1, S3
# 88      geralmente    ge.ral.men.te       S1, S3
# 89            hoje            ho.je           S2
# 90          imenso         i.men.so       S1, S3
# 91              já               já
# 92              lá               lá
# 93            logo            lo.go           S2
# 94           longe           lon.ge           S1
# 95            mais             mais
# 96             mal              mal
# 97           menos           me.nos           S3
# 98           mesmo           mes.mo           S1
# 99           muito           mui.to           S2
# 100           nada            na.da           S2
# 101            não              não
# 102            nem              nem
# 103    normalmente   nor.mal.men.te           S1
# 104          nunca           nun.ca           S1
# 105            ora             o.ra           S3
# 106           pois             pois
# 107       portanto       por.tan.to           S1
# 108          pouco           pou.co           S2
# 109       primeiro       pri.mei.ro           S3
# 110          quase           qua.se           S3
# 111    rapidamente  ra.pi.da.men.te   S1, S2, S3
# 112         sempre          sem.pre           S1
# 113            sim              sim
# 114             só               só
# 115      sobretudo     so.bre.tu.do           S2
# 116         talvez          tal.vez           S1
# 117         também          tam.bém           S1
# 118          tanto           tan.to           S1
# 119            tão              tão
# 120          tarde           tar.de           S1
# 121              o                o
# 122             um               um
# 123             ao               ao
# 124           como            co.mo           S3
# 125              e                e
# 126       enquanto       en.quan.to           S1
# 127            mas              mas
# 128             ou               ou
# 129           para            pa.ra           S3
# 130           pois             pois
# 131            por              por
# 132         porque          por.que           S1
# 133         quando          quan.do           S1
# 134            que              que
# 135             se               se
# 136            sem              sem
# 137             ah               ah
# 138              ó                ó
# 139             oh               oh
# 140            olá             o.lá           S3
# 141        abóbora       a.bó.bo.ra       S2, S3
# 142         abraço         a.bra.ço           S2
# 143          abril           a.bril           S2
# 144           ação            a.ção           S2
# 145       acidente      a.ci.den.te       S1, S2
# 146         açúcar         a.çú.car           S2
# 147         adulto         a.dul.to       S1, S2
# 148         agosto         a.gos.to       S1, S2
# 149           água            á.gua           S2
# 150          ajuda          a.ju.da           S2
# 151         aldeia         al.dei.a       S1, S5
# 152        alegria       a.le.gri.a   S2, S3, S7
# 153           alho            a.lho           S4
# 154         almoço         al.mo.ço       S1, S2
# 155         altura         al.tu.ra       S1, S3
# 156          aluno          a.lu.no           S3
# 157        amizade       a.mi.za.de       S2, S3
# 158           amor            a.mor           S3
# 159         animal         a.ni.mal           S3
# 160            ano             a.no           S3
# 161    apartamento  a.par.ta.men.to   S1, S2, S3
# 162             ar               ar
# 163           área           á.re.a       S3, S7
# 164        armário       ar.má.ri.o   S1, S3, S7
# 165          arroz           ar.roz           S1
# 166         artigo         ar.ti.go       S1, S2
# 167         árvore         ár.vo.re       S1, S3
# 168            asa             a.sa           S3
# 169        atenção        a.ten.ção       S1, S2
# 170      atividade    a.ti.vi.da.de           S2
# 171           ator            a.tor           S2
# 172           aula            au.la           S3
# 173          autor           au.tor           S2
# 174            ave             a.ve           S2
# 175        avenida       a.ve.ni.da       S2, S3
# 176          avião          a.vi.ão       S2, S6
# 177            avô             a.vô           S2
# 178         azeite         a.zei.te       S2, S3
# 179       bacalhau       ba.ca.lhau       S2, S4
# 180         bairro          bair.ro           S1
# 181          banho           ba.nho           S4
# 182          barba           bar.ba           S1
# 183          barco           bar.co           S1
# 184        barulho        ba.ru.lho       S3, S4
# 185         batata         ba.ta.ta           S2
# 186           bebé            be.bé           S2
# 187         bebida         be.bi.da           S2
# 188       beijinho       bei.ji.nho       S2, S4
# 189      bicicleta     bi.ci.cle.ta           S2
# 190           bife            bi.fe           S2
# 191        bilhete        bi.lhe.te       S2, S4
# 192      boa-tarde      bo.a tar.de  S1, S7, S12
# 193           boca            bo.ca           S2
# 194            boi              boi
# 195           bola            bo.la           S3
# 196           bolo            bo.lo           S3
# 197        bom-dia         bom di.a      S7, S12
# 198         boneca         bo.ne.ca       S2, S3
# 199         boneco         bo.ne.co       S2, S3
# 200          braço           bra.ço           S2
# 201      brinquedo      brin.que.do       S1, S2
# 202         buraco         bu.ra.co       S2, S3
# 203         cabeça         ca.be.ça           S2
# 204         cabelo         ca.be.lo       S2, S3
# 205        caderno        ca.der.no       S1, S2
# 206           café            ca.fé           S2
# 207          calor           ca.lor           S3
# 208           cama            ca.ma           S3
# 209        caminho        ca.mi.nho       S3, S4
# 210         camisa         ca.mi.sa           S3
# 211          campo           cam.po           S1
# 212         canção          can.ção           S1
# 213         canela         ca.ne.la           S3
# 214          canto           can.to           S1
# 215            cão              cão
# 216           cara            ca.ra           S3
# 217       carnaval       car.na.val       S1, S2
# 218          carne           car.ne           S1
# 219          carro           car.ro           S1
# 220          carta           car.ta           S1
# 221           casa            ca.sa           S3
# 222          casca           cas.ca           S1
# 223           caso            ca.so           S3
# 224       castanha       cas.ta.nha       S1, S4
# 225         cavalo         ca.va.lo       S2, S3
# 226         cebola         ce.bo.la       S2, S3
# 227        cenoura        ce.nou.ra           S3
# 228         centro          cen.tro           S1
# 229        certeza        cer.te.za       S1, S3
# 230            céu              céu
# 231           chão             chão
# 232          chave           cha.ve           S2
# 233         cheiro          chei.ro           S3
# 234      chocolate     cho.co.la.te       S2, S3
# 235       chouriço       chou.ri.ço       S2, S3
# 236          chuva           chu.va           S2
# 237         cidade         ci.da.de           S2
# 238        cigarra        ci.gar.ra       S1, S2
# 239         cinema         ci.ne.ma           S3
# 240        cliente        cli.en.te       S1, S7
# 241          clube           clu.be           S2
# 242         coelho         co.e.lho       S4, S7
# 243          coisa           coi.sa           S3
# 244         colega         co.le.ga       S2, S3
# 245         colher          co.lher           S4
# 246        comboio        com.boi.o       S1, S5
# 247         comida         co.mi.da       S2, S3
# 248         compra          com.pra           S1
# 249       concurso       con.cur.so           S1
# 250       consulta       con.sul.ta           S1
# 251          conta           con.ta           S1
# 252       conversa       con.ver.sa           S1
# 253           copo            co.po           S2
# 254            cor              cor
# 255        coração        co.ra.ção       S2, S3
# 256          corda           cor.da           S1
# 257          corpo           cor.po           S1
# 258          costa           cos.ta           S1
# 259        cozinha        co.zi.nha       S3, S4
# 260          creme           cre.me           S3
# 261        criança        cri.an.ça       S1, S7
# 262        cuidado        cui.da.do           S2
# 263          curso           cur.so           S1
# 264           data            da.ta           S2
# 265           dedo            de.do           S2
# 266          dente           den.te           S1
# 267       desculpa       des.cul.pa           S1
# 268       desporto       des.por.to           S1
# 269           deus             deus
# 270       dezembro       de.zem.bro       S1, S3
# 271            dia             di.a           S7
# 272       dinheiro       di.nhei.ro       S3, S4
# 273        direito        di.rei.to       S2, S3
# 274         doença         do.en.ça       S1, S7
# 275        domingo        do.min.go       S1, S3
# 276           dono            do.no           S3
# 277         doutor          dou.tor           S2
# 278        empresa        em.pre.sa       S1, S3
# 279        entrada        en.tra.da       S1, S2
# 280         equipa         e.qui.pa           S2
# 281         escola         es.co.la       S1, S3
# 282         espaço         es.pa.ço       S1, S2
# 283         espera         es.pe.ra       S1, S3
# 284      estudante     es.tu.dan.te       S1, S2
# 285         estudo         es.tu.do       S1, S2
# 286           euro            eu.ro           S3
# 287        exemplo        e.xem.plo       S1, S3
# 288           fada            fa.da           S2
# 289        família       fa.mí.li.a       S3, S7
# 290        farinha        fa.ri.nha       S3, S4
# 291         feijão          fei.jão           S2
# 292          feira           fei.ra           S3
# 293         férias         fé.ri.as       S3, S7
# 294          festa           fes.ta           S1
# 295          filho           fi.lho           S4
# 296          filme           fil.me           S1
# 297            fim              fim
# 298  fim-de-semana  fim de se.ma.na      S3, S12
# 299          final           fi.nal           S3
# 300           flor             flor
# 301          folha           fo.lha           S4
# 302          força           for.ça           S1
# 303          forma           for.ma           S1
# 304        formiga        for.mi.ga       S1, S2
# 305          forno           for.no           S1
# 306          frase           fra.se           S3
# 307         frente          fren.te           S1
# 308          fruta           fru.ta           S2
# 309          fruto           fru.to           S2
# 310          fundo           fun.do           S1
# 311        futebol        fu.te.bol           S2
# 312         futuro         fu.tu.ro       S2, S3
# 313           galo            ga.lo           S3
# 314           gato            ga.to           S2
# 315           gema            ge.ma           S3
# 316          gente           gen.te           S1
# 317           golo            go.lo           S3
# 318          gosto           gos.to           S1
# 319           gota            go.ta           S2
# 320          grupo           gru.po           S2
# 321         guerra          guer.ra           S1
# 322       história      his.tó.ri.a   S1, S3, S7
# 323          homem           ho.mem           S3
# 324           hora            ho.ra           S3
# 325        horário       ho.rá.ri.o       S3, S7
# 326          horta           hor.ta           S1
# 327       hospital       hos.pi.tal       S1, S2
# 328          hotel           ho.tel           S2
# 329          idade          i.da.de           S2
# 330          ideia          i.dei.a       S2, S5
# 331           ilha            i.lha           S4
# 332         imagem         i.ma.gem       S2, S3
# 333         início        i.ní.ci.o   S2, S3, S7
# 334        inverno        in.ver.no           S1
# 335          irmão           ir.mão           S1
# 336        janeiro        ja.nei.ro           S3
# 337         janela         ja.ne.la           S3
# 338         jardim          jar.dim           S1
# 339        jogador        jo.ga.dor           S2
# 340           jogo            jo.go           S2
# 341          jovem           jo.vem           S2
# 342          julho           ju.lho           S4
# 343          junho           ju.nho           S4
# 344           lado            la.do           S2
# 345           leão            le.ão           S6
# 346         legume         le.gu.me       S2, S3
# 347          leite           lei.te           S2
# 348          lenda           len.da           S1
# 349          letra           le.tra           S2
# 350         língua          lín.gua           S1
# 351          linha           li.nha           S4
# 352          lista           lis.ta           S1
# 353          livro           li.vro           S2
# 354          local           lo.cal           S2
# 355           loja            lo.ja           S2
# 356            lua             lu.a           S8
# 357          lugar           lu.gar           S2
# 358           lume            lu.me           S3
# 359            luz              luz
# 360         macaco         ma.ca.co           S2
# 361        madeira        ma.dei.ra       S2, S3
# 362           maio            mai.o           S5
# 363           mala            ma.la           S3
# 364           mamã            ma.mã           S3
# 365        maneira        ma.nei.ra           S3
# 366          manhã           ma.nhã           S4
# 367       manteiga       man.tei.ga       S1, S2
# 368            mão              mão
# 369        máquina        má.qui.na       S2, S3
# 370            mar              mar
# 371          marca           mar.ca           S1
# 372          março           mar.ço           S1
# 373      margarina     mar.ga.ri.na       S1, S3
# 374         marido         ma.ri.do       S2, S3
# 375           mata            ma.ta           S2
# 376       material      ma.te.ri.al   S2, S3, S7
# 377         médico         mé.di.co           S2
# 378           medo            me.do           S2
# 379           meia            mei.a           S5
# 380           meio            mei.o           S5
# 381            mel              mel
# 382         menino         me.ni.no           S3
# 383            mês              mês
# 384           mesa            me.sa           S3
# 385          metro           me.tro           S2
# 386         minuto         mi.nu.to       S2, S3
# 387           modo            mo.do           S2
# 388        momento        mo.men.to       S1, S3
# 389       montanha       mon.ta.nha       S1, S4
# 390          morte           mor.te           S1
# 391          mosca           mos.ca           S1
# 392         mulher          mu.lher           S4
# 393          mundo           mun.do           S1
# 394          museu           mu.seu           S3
# 395         música         mú.si.ca       S2, S3
# 396          natal           na.tal           S2
# 397       natureza      na.tu.re.za       S2, S3
# 398           neve            ne.ve           S2
# 399          noite           noi.te           S2
# 400           nome            no.me           S3
# 401        notícia       no.tí.ci.a       S2, S7
# 402       novembro       no.vem.bro       S1, S2
# 403            noz              noz
# 404         número         nú.me.ro           S3
# 405          nuvem           nu.vem           S2
# 406           obra            o.bra           S2
# 407           olho            o.lho           S4
# 408         origem         o.ri.gem       S2, S3
# 409           osso            os.so           S1
# 410         outono         ou.to.no       S2, S3
# 411        outubro        ou.tu.bro           S2
# 412            ovo             o.vo           S2
# 413          padre           pa.dre           S2
# 414            pai              pai
# 415           país            pa.ís          S11
# 416        palavra        pa.la.vra       S2, S3
# 417         panela         pa.ne.la           S3
# 418            pão              pão
# 419          papel           pa.pel           S2
# 420         parede         pa.re.de       S2, S3
# 421          parte           par.te           S1
# 422        pássaro        pás.sa.ro       S1, S3
# 423          passo           pas.so           S1
# 424           pata            pa.ta           S2
# 425            pau              pau
# 426            paz              paz
# 427             pé               pé
# 428          pedra           pe.dra           S2
# 429          peixe           pei.xe           S3
# 430           pele            pe.le           S3
# 431           pena            pe.na           S3
# 432       pergunta       per.gun.ta           S1
# 433          perna           per.na           S1
# 434         pessoa         pes.so.a       S1, S7
# 435        planeta        pla.ne.ta       S2, S3
# 436         planta          plan.ta           S1
# 437             pó               pó
# 438        polícia       po.lí.ci.a   S2, S3, S7
# 439          ponto           pon.to           S1
# 440          porta           por.ta           S1
# 441           povo            po.vo           S2
# 442          praia           prai.a           S5
# 443          prato           pra.to           S2
# 444          preço           pre.ço           S2
# 445       presente       pre.sen.te       S1, S3
# 446      primavera     pri.ma.ve.ra       S2, S3
# 447          primo           pri.mo           S3
# 448       problema       pro.ble.ma       S2, S3
# 449        produto        pro.du.to           S2
# 450      professor      pro.fes.sor       S1, S2
# 451       programa       pro.gra.ma       S2, S3
# 452         quarto          quar.to           S1
# 453         queijo          quei.jo           S2
# 454         quinta          quin.ta           S1
# 455          rádio          rá.di.o       S2, S7
# 456           ramo            ra.mo           S3
# 457       rapariga      ra.pa.ri.ga       S2, S3
# 458          rapaz           ra.paz           S2
# 459         raposa         ra.po.sa       S2, S3
# 460          razão           ra.zão           S3
# 461        receita        re.cei.ta           S2
# 462         região         re.gi.ão       S2, S6
# 463            rei              rei
# 464       respeito       res.pei.to       S1, S2
# 465       resposta       res.pos.ta           S1
# 466    restaurante   res.tau.ran.te       S1, S3
# 467        revista        re.vis.ta       S1, S2
# 468            rio             ri.o           S7
# 469          roupa           rou.pa           S2
# 470            rua             ru.a           S8
# 471         sábado         sá.ba.do           S2
# 472          sabor           sa.bor           S2
# 473           saco            sa.co           S2
# 474            sal              sal
# 475           sala            sa.la           S3
# 476          santo           san.to           S1
# 477         sapato         sa.pa.to           S2
# 478       sardinha       sar.di.nha       S1, S4
# 479          saúde          sa.ú.de      S2, S11
# 480         semana         se.ma.na           S3
# 481        semente        se.men.te       S1, S3
# 482         senhor          se.nhor           S4
# 483        serviço        ser.vi.ço       S1, S2
# 484       setembro       se.tem.bro       S1, S2
# 485          sítio          sí.ti.o       S2, S7
# 486            sol              sol
# 487        soldado        sol.da.do       S1, S2
# 488            som              som
# 489          sonho           so.nho           S4
# 490           sopa            so.pa           S2
# 491          sorte           sor.te           S1
# 492            sul              sul
# 493           sumo            su.mo           S3
# 494         tapete         ta.pe.te           S2
# 495          tarde           tar.de           S1
# 496      televisão     te.le.vi.são       S2, S3
# 497    temperatura  tem.pe.ra.tu.ra   S1, S2, S3
# 498          tempo           tem.po           S1
# 499          terra           ter.ra           S1
# 500          texto           tex.to           S1
# 501            tio             ti.o           S7
# 502           tipo            ti.po           S2
# 503       trabalho       tra.ba.lho       S2, S4
# 504         tronco          tron.co           S1
# 505          turma           tur.ma           S1
# 506           urso            ur.so           S1
# 507            uva             u.va           S2
# 508          valor           va.lor           S3
# 509          venda           ven.da           S1
# 510       vendedor       ven.de.dor       S1, S2
# 511          vento           ven.to           S1
# 512          verão           ve.rão           S3
# 513        verdade        ver.da.de       S1, S2
# 514            vez              vez
# 515         viagem         vi.a.gem       S2, S7
# 516           vida            vi.da           S2
# 517          vídeo          ví.de.o       S2, S7
# 518          vinho           vi.nho           S4
# 519        vizinho        vi.zi.nho       S3, S4
# 520          volta           vol.ta           S1
# 521        vontade        von.ta.de       S1, S2
# 522            voz              voz
# 523           zona            zo.na           S3
# 524          cinco           cin.co           S1
# 525            dez              dez
# 526           dois             dois
# 527           doze            do.ze           S3
# 528           oito            oi.to           S2
# 529         quatro          qua.tro           S2
# 530        segundo        se.gun.do       S1, S2
# 531           seis             seis
# 532           sete            se.te           S2
# 533       terceiro       ter.cei.ro       S1, S3
# 534           três             três
# 535              a                a
# 536            com              com
# 537         contra          con.tra           S1
# 538             de               de
# 539          desde           des.de           S1
# 540        durante        du.ran.te       S1, S3
# 541             em               em
# 542          entre           en.tre           S1
# 543            sem              sem
# 544          sobre           so.bre           S2
# 545           algo            al.go           S1
# 546         alguém          al.guém           S1
# 547          algum           al.gum           S1
# 548         aquele         a.que.le       S2, S3
# 549         aquilo         a.qui.lo       S2, S3
# 550           cada            ca.da           S2
# 551          certo           cer.to           S1
# 552           esse            es.se           S1
# 553           este            es.te           S1
# 554             eu               eu
# 555           isso            is.so           S1
# 556           isto            is.to           S1
# 557         nenhum          ne.nhum           S4
# 558        ninguém         nin.guém           S1
# 559           onde            on.de           S1
# 560          outro           ou.tro           S2
# 561         porquê          por.quê           S1
# 562        próprio        pró.pri.o       S2, S7
# 563           qual             qual
# 564       qualquer        qual.quer           S1
# 565         quanto          quan.to           S1
# 566           quem             quem
# 567            tal              tal
# 568          tanto           tan.to           S1
# 569           todo            to.do           S2
# 570           tudo            tu.do           S2
# 571          único          ú.ni.co       S2, S3
# 572          abrir           a.brir           S2
# 573         acabar         a.ca.bar           S2
# 574          achar           a.char           S2
# 575      acontecer     a.con.te.cer       S1, S2
# 576        acordar        a.cor.dar       S1, S2
# 577      acreditar     a.cre.di.tar           S2
# 578         adorar         a.do.rar       S2, S3
# 579      agradecer     a.gra.de.cer           S2
# 580         ajudar         a.ju.dar           S2
# 581        almoçar        al.mo.çar       S1, S2
# 582           amar            a.mar           S3
# 583          andar           an.dar           S1
# 584        apanhar        a.pa.nhar       S2, S4
# 585       aparecer      a.pa.re.cer       S2, S3
# 586       aprender       a.pren.der       S1, S2
# 587       arranjar       ar.ran.jar           S1
# 588        arrumar        ar.ru.mar       S1, S3
# 589         atirar         a.ti.rar       S2, S3
# 590          bater           ba.ter           S2
# 591          beber           be.ber           S2
# 592        brincar         brin.car           S1
# 593           cair            ca.ir           S9
# 594         cantar          can.tar           S1
# 595          casar           ca.sar           S3
# 596         chamar          cha.mar           S3
# 597         chegar          che.gar           S2
# 598         chorar          cho.rar           S3
# 599         chover          cho.ver           S2
# 600        colocar        co.lo.car       S2, S3
# 601        começar        co.me.çar       S2, S3
# 602          comer           co.mer           S3
# 603        comprar         com.prar           S1
# 604       conhecer       co.nhe.cer       S2, S4
# 605         contar          con.tar           S1
# 606      continuar     con.ti.nu.ar   S1, S3, S8
# 607      conversar      con.ver.sar           S1
# 608         correr          cor.rer           S1
# 609         cortar          cor.tar           S1
# 610       costumar       cos.tu.mar       S1, S3
# 611       cozinhar       co.zi.nhar       S3, S4
# 612        crescer         cres.cer           S1
# 613         cuidar          cui.dar           S2
# 614         custar          cus.tar           S1
# 615         dançar          dan.çar           S1
# 616            dar              dar
# 617        decidir        de.ci.dir           S2
# 618         deitar          dei.tar           S2
# 619         deixar          dei.xar           S3
# 620        demorar        de.mo.rar           S3
# 621         descer          des.cer           S1
# 622      desculpar      des.cul.par           S1
# 623          dever           de.ver           S2
# 624          dizer           di.zer           S3
# 625         dormir          dor.mir           S1
# 626         encher          en.cher           S1
# 627      encontrar      en.con.trar           S1
# 628        enganar        en.ga.nar       S1, S3
# 629         entrar          en.trar           S1
# 630       entregar       en.tre.gar       S1, S2
# 631         enviar         en.vi.ar       S1, S7
# 632       escolher       es.co.lher       S1, S4
# 633       esconder       es.con.der           S1
# 634        esperar        es.pe.rar       S1, S3
# 635       esquecer       es.que.cer       S1, S2
# 636          estar           es.tar           S1
# 637        estudar        es.tu.dar       S1, S2
# 638          falar           fa.lar           S3
# 639         faltar          fal.tar           S1
# 640          fazer           fa.zer           S3
# 641         fechar          fe.char           S2
# 642         ferver          fer.ver           S1
# 643          ficar           fi.car           S2
# 644          fugir           fu.gir           S2
# 645         ganhar          ga.nhar           S4
# 646         gastar          gas.tar           S1
# 647         gostar          gos.tar           S1
# 648         gritar          gri.tar           S2
# 649        guardar         guar.dar           S1
# 650          haver           ha.ver           S2
# 651       inventar       in.ven.tar           S1
# 652             ir               ir
# 653         jantar          jan.tar           S1
# 654          jogar           jo.gar           S2
# 655         juntar          jun.tar           S1
# 656          lavar           la.var           S2
# 657        lembrar         lem.brar           S1
# 658            ler              ler
# 659       levantar       le.van.tar       S1, S2
# 660          levar           le.var           S2
# 661          ligar           li.gar           S2
# 662         limpar          lim.par           S1
# 663          lutar           lu.tar           S2
# 664         mandar          man.dar           S1
# 665         manter          man.ter           S1
# 666          meter           me.ter           S2
# 667          mexer           me.xer           S3
# 668          morar           mo.rar           S3
# 669         morrer          mor.rer           S1
# 670        mostrar         mos.trar           S1
# 671          mudar           mu.dar           S2
# 672          nadar           na.dar           S2
# 673         nascer          nas.cer           S1
# 674       oferecer      o.fe.re.cer       S2, S3
# 675          olhar           o.lhar           S4
# 676          ouvir           ou.vir           S2
# 677          pagar           pa.gar           S2
# 678          parar           pa.rar           S3
# 679        parecer        pa.re.cer       S2, S3
# 680         partir          par.tir           S1
# 681         passar          pas.sar           S1
# 682        passear        pas.se.ar       S1, S7
# 683          pedir           pe.dir           S2
# 684          pegar           pe.gar           S2
# 685         pensar          pen.sar           S1
# 686       perceber       per.ce.ber       S1, S2
# 687         perder          per.der           S1
# 688      perguntar      per.gun.tar           S1
# 689          poder           po.der           S2
# 690            pôr              pôr
# 691       precisar       pre.ci.sar       S2, S3
# 692       preparar       pre.pa.rar       S2, S3
# 693       procurar       pro.cu.rar       S2, S3
# 694          puxar           pu.xar           S3
# 695         querer          que.rer           S3
# 696        receber        re.ce.ber           S2
# 697        repetir        re.pe.tir           S2
# 698       respirar       res.pi.rar       S1, S3
# 699      responder      res.pon.der           S1
# 700            rir              rir
# 701          saber           sa.ber           S2
# 702           sair            sa.ir           S9
# 703         saltar          sal.tar           S1
# 704          secar           se.car           S2
# 705         seguir          se.guir           S2
# 706         sentar          sen.tar           S1
# 707         sentir          sen.tir           S1
# 708            ser              ser
# 709         servir          ser.vir           S1
# 710         sobrar          so.brar           S2
# 711         sofrer          so.frer           S2
# 712         sonhar          so.nhar           S4
# 713         sorrir          sor.rir           S1
# 714          subir           su.bir           S2
# 715         tentar          ten.tar           S1
# 716            ter              ter
# 717          tirar           ti.rar           S3
# 718          tocar           to.car           S2
# 719          tomar           to.mar           S3
# 720         tornar          tor.nar           S1
# 721      trabalhar      tra.ba.lhar       S2, S4
# 722         tratar          tra.tar           S2
# 723         trazer          tra.zer           S3
# 724           usar            u.sar           S3
# 725         vender          ven.der           S1
# 726            ver              ver
# 727         vestir          ves.tir           S1
# 728            vir              vir
# 729        visitar        vi.si.tar       S2, S3
# 730          viver           vi.ver           S2
# 731           voar            vo.ar           S7
# 732         voltar          vol.tar           S1
